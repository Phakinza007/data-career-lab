# %% [markdown]
# # Capstone: โปรเจกต์ end-to-end
#
# Notebook นี้เป็นจุดเริ่มต้นสำหรับโปรเจกต์ capstone — ไม่จำเป็นต้องเริ่มจากศูนย์
#
# ก่อนเริ่ม อ่านเกณฑ์ตรวจงานตัวเอง (self-review checklist) ในบทเรียน `Capstone: โปรเจกต์ end-to-end` บนเว็บก่อน แล้วกลับมาเปิดไฟล์นี้ต่อ
#
# โครงสร้างของ notebook นี้: ตั้งคำถาม → เตรียม/สำรวจข้อมูล → วิเคราะห์ → กราฟ → เขียน insight → self-review

# %%
import os
if not os.path.exists('data-career-lab'):
    os.system('git clone https://github.com/Phakinza007/data-career-lab.git')
os.chdir('data-career-lab')

import pandas as pd
customers = pd.read_csv('public/data/customers.csv')
orders = pd.read_csv('public/data/orders.csv')
order_items = pd.read_csv('public/data/order_items.csv')
products = pd.read_csv('public/data/products.csv')
events = pd.read_csv('public/data/events.csv')
print('โหลดข้อมูลสำเร็จ:', len(customers), len(orders), len(order_items), len(products), len(events))

# %% [markdown]
# ## 1. ตั้งคำถาม
#
# เลือกคำถามธุรกิจ 1 ข้อจากตัวอย่างในบทเรียน หรือคิดเองก็ได้ เขียนคำถามที่เลือกไว้ในเซลล์ถัดไป

# %%
# เขียนคำถามของคุณเป็นคอมเมนต์ตรงนี้
# ตัวอย่าง: ลูกค้ากลุ่มไหนควรได้รับความสำคัญมากที่สุด?

# %% [markdown]
# ## 2. เตรียมและสำรวจข้อมูล

# %%
# pd.read_csv, .merge, .groupby ฯลฯ — เตรียมข้อมูลให้พร้อมตอบคำถามของคุณ

# %% [markdown]
# ## 3. วิเคราะห์

# %% [markdown]
# ## 4. กราฟ
#
# เลือกชนิดกราฟให้ตรงกับคำถาม (ทบทวนบท `เลือกกราฟให้ตรงคำถาม`) อย่าลืมใส่ title/xlabel/ylabel ให้ครบ

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 5. เขียน insight
#
# ทบทวนโครงสร้าง insight ที่ดีจากบท `เขียน insight จากกราฟ`: สิ่งที่เปลี่ยนไป + เปลี่ยนไปเท่าไร (ตัวเลข) + เทียบกับอะไร (baseline) + "แล้วไง" (action)

# %% [markdown]
# _เขียน insight สุดท้ายของคุณตรงนี้_

# %% [markdown]
# ## Self-review
#
# เช็คก่อนเผยแพร่:
#
# - [ ] คำถามชัดเจน ตอบได้จริงด้วยข้อมูลที่มี
# - [ ] ใช้ pandas/SQL ถูกต้อง ไม่มี error หรือ logic ผิด
# - [ ] มีกราฟอย่างน้อย 1 อันที่เลือกชนิดถูกกับคำถาม พร้อม title/label ครบ
# - [ ] มี insight อย่างน้อย 1 ข้อที่มีทั้งตัวเลข เทียบกับ baseline และ "แล้วไง"
# - [ ] notebook รันได้ทั้งไฟล์จากบนลงล่างโดยไม่ error
# - [ ] ถ้าจะเผยแพร่ มี README สั้นๆ อธิบายว่าโปรเจกต์นี้ตอบคำถามอะไร
